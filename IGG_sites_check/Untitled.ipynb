# %%
pip install unlzw3 requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ncompress
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install compress
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
