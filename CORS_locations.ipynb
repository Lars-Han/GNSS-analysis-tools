# %%
from pyproj import Transformer
import pandas as pd

# Transformer from NZTM to WGS84
transformer = Transformer.from_crs("EPSG:2193", "EPSG:4326", always_xy=True)

# Convert
lon, lat = transformer.transform(easting, northing)

# Create DataFrame
df = pd.DataFrame({
    "longitude": lon,
    "latitude": lat,
    "elevation": height
})
